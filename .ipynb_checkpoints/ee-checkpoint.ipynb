# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# 한글 폰트 문제 해결
# matplotlib는 한글폰트를 지원하지 않음
# is정보
import platform
# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# 시각화 도구
from matplotlib import pyplot as plt
# %matplotlib inline
# uniccode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin': #os 가 mac일때
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
    path = 'C:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font',family = font_name)
else:
    print("Unknown system")

# %%
clien=pd.read_csv('./clien.csv')

# %%
clien.loc[clien['dayofweek']==0,"요일"]='월'
clien.loc[clien['dayofweek']==1,"요일"]='화'
clien.loc[clien['dayofweek']==2,"요일"]='수'
clien.loc[clien['dayofweek']==3,"요일"]='목'
clien.loc[clien['dayofweek']==4,"요일"]='금'
clien.loc[clien['dayofweek']==5,"요일"]='토'
clien.loc[clien['dayofweek']==6,"요일"]='일'
cats = [ '월', '화', '수', '목', '금', '토', '일']

# %%
plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rc('legend', fontsize=20)
plt.rc('figure', titlesize=20)
fig, axes = plt.subplots(nrows=2)
fig.set_size_inches(18,30)

# train data
plt.sca(axes[0])
plt.xticks(rotation=30, ha='right') # x축 글자
axes[0].set(ylabel='Count', title='시간당 글 수')
sns.countplot(data=clien, x='hour', ax=axes[0])

#test data
plt.sca(axes[1])
plt.xticks(rotation=30, ha='right')
axes[1].set(ylabel='Count', title='요일별 글 수')
sns.countplot(data=clien, x='요일', ax=axes[1],
             order = cats)

# %% [markdown]
# 21시가 글리젠이 제일 많이 되고 있음
# 11시와 22시가 그다음을 달리고 있음
# 대체로 10시부터 23시까지는 크게 차이가 나지 않는다.
#
# 아침에 업무를 대략 정리하고 점심먹기전 잠깐 글을 쓰는 경우나
# 퇴근후에 저녁을 먹고 글을 쓰는 경우 때문에 그렇다
#
# 대체적으로 월~금까지는 글 리젠수가 비슷하나 목요일이 약간 높은 경향을 나타냄
#
# 토요일 일요일은 다른날에 비해 3/4정도 밖에 안됨

# %%
jan = clien[clien['month']==1]
dec = clien[clien['month']==12]

# %%
# 다른월의 날짜가 같은것보다는 공휴일 여부가 더 영향을 미칠것 같으므로
# 날짜별 그래프는 월별로 보기로 한다
fig, axes = plt.subplots(nrows=2)
fig.set_size_inches(18,15)

#test data
plt.sca(axes[0])
plt.xticks(rotation=30, ha='right')
axes[0].set(ylabel='Count', title='1월 일별 글수')
sns.countplot(data=jan, x='day', ax=axes[0])

plt.sca(axes[1])
plt.xticks(rotation=30, ha='right')
axes[1].set(ylabel='Count', title='12월 일별 글수')
sns.countplot(data=dec, x='day', ax=axes[1])

# %% [markdown]
# 1월은 명절 휴일일 24,25,26,27의 글 리젠이 상대적으로 적다 특히 25일은 처참한 정도
# 1월 1일은 특이사항으로 엄청 높다 (신년축하)
# 3,4,5 금토일
#
# 12월
# 위에와 마찬가지로 12.28,29 토일등의 리젠수가 적다
# 특이점으로 26일리젠수가 높다
#
#
# 금요일, 크리스마스 전날인 경우엔 글리젠이 적고 크리스마스 후에는 글리젠이 많다.
# 금요일이나, 공휴일 전에는 다음날 쉬는 이점이 있으므로 저녁 약속을 잡아 그런것 같다
# (몇시부터 적어지기 시작하는지 체크 - 평일과 함께 체크)

# %%
clien[['추천수','리플수','조회수int']].describe()
# Out:
#                  추천수            리플수         조회수int
# count  133743.000000  133743.000000  133743.000000
# mean        5.186627       9.792288    3466.492706
# std        23.594775      14.658880    6051.743023
# min         0.000000       0.000000      29.000000
# 25%         0.000000       3.000000     972.000000
# 50%         0.000000       6.000000    1856.000000
# 75%         1.000000      12.000000    3421.000000
# max      1058.000000     733.000000  180100.000000

# %%
perday=clien.pivot_table('조회수int',index = "hour", columns = 'dayofweek',aggfunc='mean')

# %%
perday.columns = ['월','화','수','목','금','토','일']

# %%
perday
# Out:
# dayofweek            0            1            2            3             4  \
# hour
# 0          3727.067816  3726.516129  2554.795201  3648.984359   3117.286523
# 1          4547.916268  4519.012739  4460.266376  4520.491870   4484.837067
# 2          5040.485981  4384.570492  4478.332168  5133.164706   4566.410480
# 3          6928.822086  5563.731707  5646.805195  5366.103175   6563.432000
# 4          8210.168421  6316.762887  5737.500000  5921.907216   6567.666667
# 5          7878.967742  9247.622642  7927.846154  7259.923913  10169.977528
# 6          9524.196581  6847.486667  6460.899371  8662.630952   7482.366667
# 7          7132.705455  6155.156658  6493.284091  7485.771812   7570.692308
# 8          6070.843137  4230.011873  4167.969402  4576.997195   5259.702265
# 9          3636.875281  3140.814324  2992.218605  2977.143482   3554.943662
# 10         3012.904340  2624.518169  2737.212898  2727.866213   2880.498751
# 11         3103.686275  2641.675226  2194.502955  2668.562586   3190.164844
# 12         3449.379175  3378.338287  2746.597986  3297.656170   3342.252101
# 13         3424.042533  3031.405255  2873.881369  3044.819763   3300.589316
# 14         3237.200401  3216.742437  3102.472666  3296.349515   3303.170018
# 15         3565.464105  2955.600806  2988.765158  3486.475786   3065.517928
# 16         3042.997333  3217.281197  3376.181574  3069.385980   3187.441472
# 17         3385.018041  3289.064904  3445.890625  3465.055111   3165.120000
# 18         2637.296970  2832.220779  3104.479882  2277.535740   3067.818099
# 19         2389.528728  2719.231397  2877.334278  2385.416600   3420.467961
# 20         2566.641882  2663.140138  2941.726923  2537.158106   3546.060302
# 21         2824.181751  2973.204565  2179.159604  2480.377761   3210.342916
# 22         3241.800338  3289.642857  2467.616105  2943.416880   3095.182331
# 23         3810.071283  3178.587629  2785.240973  3108.844075   3465.728797
#
# dayofweek            5            6
# hour
# 0          4025.842434  4054.074932
# 1          4860.942308  5202.124150
# 2          6096.235577  5105.589041
# 3          5402.496000  4757.880682
# 4          7980.098592  6169.955357
# 5          8340.734940  9838.149425
# 6          9044.944444  9529.602273
# 7          7088.517045  8675.043478
# 8          6690.218289  7285.451957
# 9          4812.746154  7147.532803
# 10         4134.933246  4870.401799
# 11         3881.090909  4457.747297
# 12         3755.510444  3564.790013
# 13         3363.503311  3620.592411
# 14         3674.552534  3797.570295
# 15         3722.820402  3722.304651
# 16         3640.311258  4189.444709
# 17         4148.286776  3334.385218
# 18         3457.558290  3478.576659
# 19         3579.158491  3857.720272
# 20         4251.641089  3603.818182
# 21         3668.073491  3755.170898
# 22         3184.517032  3781.952616
# 23         3559.492178  3463.549217

# %%
perday['ind'] = perday.index

# %%
perday_melted = pd.melt(perday, id_vars = ['ind'])
perday_melted
# Out:
#      ind variable        value
# 0      0        월  3727.067816
# 1      1        월  4547.916268
# 2      2        월  5040.485981
# 3      3        월  6928.822086
# 4      4        월  8210.168421
# ..   ...      ...          ...
# 163   19        일  3857.720272
# 164   20        일  3603.818182
# 165   21        일  3755.170898
# 166   22        일  3781.952616
# 167   23        일  3463.549217
#
# [168 rows x 3 columns]

# %%
### 멜트해서 hue로 나눠야함???

fig, axes = plt.subplots()
fig.set_size_inches(20,10)

# train data
plt.sca(axes)
plt.xticks(rotation=30, ha='right') # x축 글자
sns.barplot(perday_melted['ind'],perday_melted['value'], data = perday_melted, hue='variable', ax=axes)
axes.set(xlabel='시간',ylabel='Count', title='시간별 조회수 평균')
# Out:
# [Text(0, 0.5, 'Count'), Text(0.5, 0, '시간'), Text(0.5, 1.0, '시간별 조회수 평균')]

# %%
perday = perday.iloc[:,0:7]

# %%
# fig, axes = plt.subplots(8,1, figsize = (20,90))
# axes
# axes[0].plot(perday)
# # for i in range(len(perday.columns)):
# #     axes[i,0].plot(kind='bar')
# for i in range(len(perday.columns)):
#     axes[int(i)+(1)].plot(perday.iloc[:,i])

# 위와 아래는 동일함
# 아래대로 써야 타입이랑 바꿔주기 쉽다






fig, axes = plt.subplots(8,1, figsize = (20,90))
perday.plot(ax= axes[0], kind='bar')
# for i in range(len(perday.columns)):
#     axes[i,0].plot(kind='bar')
for i in range(len(perday.columns)):
    perday.iloc[:,i].plot(ax = axes[int(i)+1], kind = 'bar',ylim =(0,10000) ,title = str(perday.columns[i])+"요일")

# %% [markdown]
# 신기하게도 5~7사이에 쓴글들이 대체로 조회수가 높다
# 글을 쓴 시점과 읽는 시간과는 차이가 있을수 있으므로
# 새벽에 쓴글들이 유저들이 아침에 일어났을때 처음으로 접하게 되는 글이다
# 5,6,7시는 글 리젠이 적어서 몇페이지가 안되기때문에 상대적으로 읽어보기가 쉽다

# %%
perday=clien.pivot_table('추천수',index = "hour", columns = 'dayofweek',aggfunc='mean')
perday.columns = ['월','화','수','목','금','토','일']

# %%
perday
# Out:
#               월          화          수          목          금          토  \
# hour
# 0      2.993103   4.792258   4.970009   4.782065   5.416761   4.336973
# 1      4.488038   5.664544   9.045852   6.585366   8.160896   4.403846
# 2      6.345794   6.373770   4.573427   7.874510   5.834061   8.865385
# 3      9.521472   6.865854  13.253247  10.269841  12.352000   5.920000
# 4      7.842105  10.278351  13.583333   8.061856   8.468750  12.971831
# 5     14.822581  16.726415  14.282051  14.478261  35.112360   7.228916
# 6     17.487179  14.093333  15.157233  18.714286  16.080000  12.066667
# 7     12.716364  12.083551  12.261364  19.493289  14.842949   7.443182
# 8      8.827094   8.637203   8.371349   9.325386  12.029126  11.339233
# 9      5.715730   6.027409   6.400000   4.981627   6.085590   5.071154
# 10     5.665190   5.257994   6.268842   5.105064   5.710241   4.981675
# 11     6.264314   4.236641   4.217334   5.343191   5.838520   4.906417
# 12     5.395874   4.799825   5.266460   6.497872   6.056956   5.557441
# 13     4.771267   4.434713   4.048669   5.562055   4.850584   3.639735
# 14     4.833667   4.468520   4.463415   5.426375   5.269653   4.182942
# 15     4.386249   4.186290   4.743809   6.677145   4.141833   3.811782
# 16     5.051556   5.176068   6.130590   5.798986   4.660535   4.124503
# 17     4.851375   5.498397   5.300347   5.888000   3.965490   3.563150
# 18     3.370563   3.425974   4.195289   3.405776   5.011883   4.380829
# 19     6.084131   3.990926   4.882908   4.442385   5.108738   3.488050
# 20     6.846737   2.953287   5.881538   3.548154   4.251256   5.879950
# 21     4.324184   4.062553   3.351679   3.507235   4.264887   3.098425
# 22     4.375635   3.327526   4.172909   3.502984   3.107143   2.807786
# 23     4.520367   3.804983   3.726060   4.129938   3.999014   2.529483
#
#               일
# hour
# 0      3.407357
# 1      4.581633
# 2      4.352740
# 3      5.107955
# 4      3.062500
# 5     15.448276
# 6     10.579545
# 7     13.652174
# 8      8.779359
# 9      8.272366
# 10     5.169415
# 11     4.791892
# 12     4.020487
# 13     4.736842
# 14     5.057823
# 15     5.251163
# 16     4.697979
# 17     4.306831
# 18     3.913043
# 19     3.421291
# 20     3.647353
# 21     3.221680
# 22     3.680158
# 23     3.341163

# %%
fig, axes = plt.subplots(8,1, figsize = (20,90))
axes
perday.plot(ax= axes[0], kind='bar', title='시간별 추천수 평균')
# for i in range(len(perday.columns)):
#     axes[i,0].plot(kind='bar')
for i in range(len(perday.columns)):
    perday.iloc[:,i].plot(ax = axes[int(i)+1], kind = 'bar',ylim =(0,35) ,title = str(perday.columns[i])+"요일")

# %% [markdown]
# 추천도 역시 5,6,7시가 많다

# %%
clien.loc[(clien['dayofweek']==0)&(clien['hour']==5),:].sort_values('추천수',ascending = False).head(10)
# Out:
#         추천수 게시판                                  제목  리플수         아이디     조회수  \
# 101913  303  모공     지난 6개월 동안, 우리는 실감했다... feat.홍콩인   21          뿌랄  39.4 k
# 39098   218  모공                       엠팍 유저들에게 한 말씀  107       아이포니악  36.7 k
# 71729   164  모공                권은희 '여야 모두 무기명 투표하자'    3      Castle  39.2 k
# 131896  105  모공  언중위, '조선일보는 1면에 늬들 팩트체크 기사 반론 실어라'    9         예큰형  10.9 k
# 11573    21  모공                코비 브라이언트 헬리콥터 사고로 사망   72        GOLL  46.8 k
# 117130   20  모공             반포경단체 보트에 물대포 쏘는 일본 포경선    7  dvpxsodium    8748
# 88293    14  모공                  살면서 제일 이해가 안되는 사람들   19       비마민CD  10.9 k
# 131891   11  모공                      시작하는 사람들을 위한 책    7       아이포니악    6962
# 117128   11  모공                      오랜만에 어머니가 오셨어요    7         다리미    5929
# 54279    10  모공                 오늘의 뉴스공장 2020.01.06    5   그아이디가알고싶다    7930
#
#                          날짜      문서번호  사진유무  조회수int  ...  year  month  day  \
# 101913  2019-12-16 05:07:59  14396059     0   39400  ...  2019     12   16
# 39098   2020-01-13 05:16:54  14490018     1   36700  ...  2020      1   13
# 71729   2019-12-30 05:35:47  14442344     1   39200  ...  2019     12   30
# 131896  2019-12-02 05:06:52  14349402     1   10900  ...  2019     12    2
# 11573   2020-01-27 05:05:15  14530756     0   46800  ...  2020      1   27
# 117130  2019-12-09 05:24:07  14372679     0    8748  ...  2019     12    9
# 88293   2019-12-23 05:14:41  14417634     1   10900  ...  2019     12   23
# 131891  2019-12-02 05:56:31  14349414     1    6962  ...  2019     12    2
# 117128  2019-12-09 05:47:56  14372684     0    5929  ...  2019     12    9
# 54279   2020-01-06 05:07:33  14467860     0    7930  ...  2020      1    6
#
#         hour  minute  second  dayofweek      설명 holiday  요일
# 101913     5       7      59          0     NaN       0   월
# 39098      5      16      54          0     NaN       0   월
# 71729      5      35      47          0     NaN       0   월
# 131896     5       6      52          0     NaN       0   월
# 11573      5       5      15          0  설날대체휴일       1   월
# 117130     5      24       7          0     NaN       0   월
# 88293      5      14      41          0     NaN       0   월
# 131891     5      56      31          0     NaN       0   월
# 117128     5      47      56          0     NaN       0   월
# 54279      5       7      33          0     NaN       0   월
#
# [10 rows x 21 columns]

# %%
clien.loc[(clien['dayofweek']==4)&(clien['hour']==5),:].sort_values('추천수',ascending = False)
# Out:
#         추천수 게시판                               제목  리플수         아이디     조회수  \
# 77964   550  모공         내년이면 40살.. 공기업 취업했습니다...  247        MAXI  47.8 k
# 44773   462  모공                     김호창 입시전문가 페북   73   그아이디가알고싶다  47.0 k
# 44778   411  모공                          시간 여행자!  121  arctic_cat  46.9 k
# 30396   352  모공      아주대 새빨간 거짓말에 뚜껑열린 이국종교수.jpg  125       퀘스트바이  45.3 k
# 107305  219  모공  곰탕집 사건은 피고인의 거짓말이 치명타였던 것 같습니다.  284        에버랜드  49.9 k
# ...     ...  ..                              ...  ...         ...     ...
# 59876     0  모공                     진중권 좋겠네요 (2)    7      bcoder    6074
# 77956     0  모공     근데 조국 구속 기각 내용을 기레기가 기레기 했네요    4      경기도호랑이    2623
# 77959     0  모공               베네수엘라 오피스 갱신 불가입니다   13        케이로즈    6066
# 77962     0  모공              오늘의 뉴스공장 2019.12.27    0   그아이디가알고싶다    2577
# 122664    0  모공                           춥습니더..    2       선장다이스    1274
#
#                          날짜      문서번호  사진유무  조회수int  ...  year  month  day  \
# 77964   2019-12-27 05:07:58  14432843     0   47800  ...  2019     12   27
# 44773   2020-01-10 05:53:05  14481724     0   47000  ...  2020      1   10
# 44778   2020-01-10 05:31:30  14481719     0   46900  ...  2020      1   10
# 30396   2020-01-17 05:59:34  14503178     0   45300  ...  2020      1   17
# 107305  2019-12-13 05:59:55  14387641     0   49900  ...  2019     12   13
# ...                     ...       ...   ...     ...  ...   ...    ...  ...
# 59876   2020-01-03 05:09:53  14459357     1    6074  ...  2020      1    3
# 77956   2019-12-27 05:57:50  14432855     0    2623  ...  2019     12   27
# 77959   2019-12-27 05:26:43  14432850     0    6066  ...  2019     12   27
# 77962   2019-12-27 05:10:13  14432845     0    2577  ...  2019     12   27
# 122664  2019-12-06 05:20:36  14364000     1    1274  ...  2019     12    6
#
#         hour  minute  second  dayofweek   설명 holiday  요일
# 77964      5       7      58          4  NaN       0   금
# 44773      5      53       5          4  NaN       0   금
# 44778      5      31      30          4  NaN       0   금
# 30396      5      59      34          4  NaN       0   금
# 107305     5      59      55          4  NaN       0   금
# ...      ...     ...     ...        ...  ...     ...  ..
# 59876      5       9      53          4  NaN       0   금
# 77956      5      57      50          4  NaN       0   금
# 77959      5      26      43          4  NaN       0   금
# 77962      5      10      13          4  NaN       0   금
# 122664     5      20      36          4  NaN       0   금
#
# [89 rows x 21 columns]

# %%
perday=clien.pivot_table('리플수',index = "hour", columns = 'dayofweek',aggfunc='mean')

# %%
perday=clien.pivot_table('리플수',index = "hour", columns = 'dayofweek',aggfunc='mean')
perday.columns = ['월','화','수','목','금','토','일']

# %%
# fig, axes = plt.subplots(8,1, figsize = (20,90))
# axes
# axes[0].plot(perday)
# # for i in range(len(perday.columns)):
# #     axes[i,0].plot(kind='bar')
# for i in range(len(perday.columns)):
#     axes[int(i)+(1)].plot(perday.iloc[:,i])

# 위와 아래는 동일함
# 아래대로 써야 타입이랑 바꿔주기 쉽다
fig, axes = plt.subplots(8,1, figsize = (20,90))
perday.plot(ax= axes[0], kind='bar',title = '시간별 리플수 평균')
# for i in range(len(perday.columns)):
#     axes[i,0].plot(kind='bar')
for i in range(len(perday.columns)):
    perday.iloc[:,i].plot(ax = axes[int(i)+1],ylim=(0,28), kind = 'bar',title = str(perday.columns[i])+"요일")

# %% [markdown]
# 비슷한 양상을 보임
# 약간의 시간차는 있지만 5~6 시쯤 올린글에 대해서
# 수요일과 금요일 새벽이 리플이 잘 달렸다

# %%
clien.loc[(clien['dayofweek']==4)&(clien['hour']==5),:].sort_values('리플수',ascending = False).head(10)
# Out:
#         추천수 게시판                                제목  리플수         아이디     조회수  \
# 107305  219  모공   곰탕집 사건은 피고인의 거짓말이 치명타였던 것 같습니다.  284        에버랜드  49.9 k
# 77964   550  모공          내년이면 40살.. 공기업 취업했습니다...  247        MAXI  47.8 k
# 44774    25  모공                          서울물가.jpg  160     아침에커피한잔  41.9 k
# 93584     6  모공                    펌]음료수 유죄판결.jpg  137     아침에커피한잔  44.9 k
# 30396   352  모공       아주대 새빨간 거짓말에 뚜껑열린 이국종교수.jpg  125       퀘스트바이  45.3 k
# 44778   411  모공                           시간 여행자!  121  arctic_cat  46.9 k
# 44776     7  모공         [사진] '친환경'적인 도쿄올림픽 선수촌 숙소   97     zenplay  39.6 k
# 59870    64  모공  10개월 만에 210kg에서 95kg로 살 뺀 비법.JPG   86     Youtube  55.3 k
# 59865     3  모공                       알벤다졸 성기능 장애   84        JAXA  32.5 k
# 44773   462  모공                      김호창 입시전문가 페북   73   그아이디가알고싶다  47.0 k
#
#                          날짜      문서번호  사진유무  조회수int  ...  year  month  day  \
# 107305  2019-12-13 05:59:55  14387641     0   49900  ...  2019     12   13
# 77964   2019-12-27 05:07:58  14432843     0   47800  ...  2019     12   27
# 44774   2020-01-10 05:51:50  14481723     0   41900  ...  2020      1   10
# 93584   2019-12-20 05:56:22  14409210     0   44900  ...  2019     12   20
# 30396   2020-01-17 05:59:34  14503178     0   45300  ...  2020      1   17
# 44778   2020-01-10 05:31:30  14481719     0   46900  ...  2020      1   10
# 44776   2020-01-10 05:34:37  14481721     0   39600  ...  2020      1   10
# 59870   2020-01-03 05:31:32  14459365     1   55300  ...  2020      1    3
# 59865   2020-01-03 05:43:50  14459370     0   32500  ...  2020      1    3
# 44773   2020-01-10 05:53:05  14481724     0   47000  ...  2020      1   10
#
#         hour  minute  second  dayofweek   설명 holiday  요일
# 107305     5      59      55          4  NaN       0   금
# 77964      5       7      58          4  NaN       0   금
# 44774      5      51      50          4  NaN       0   금
# 93584      5      56      22          4  NaN       0   금
# 30396      5      59      34          4  NaN       0   금
# 44778      5      31      30          4  NaN       0   금
# 44776      5      34      37          4  NaN       0   금
# 59870      5      31      32          4  NaN       0   금
# 59865      5      43      50          4  NaN       0   금
# 44773      5      53       5          4  NaN       0   금
#
# [10 rows x 21 columns]

# %%
clien.loc[clien['사진유무']=="Y","사진유무"] = 1
clien.loc[clien['사진유무']=="N","사진유무"] = 0

# %%
clien[['추천수', '리플수', '사진유무', '조회수int','dayofweek', 'holiday']].corr()
# Out:
#                 추천수       리플수      사진유무    조회수int  dayofweek   holiday
# 추천수        1.000000  0.451799  0.000004  0.558741  -0.006851 -0.014517
# 리플수        0.451799  1.000000  0.014928  0.607249  -0.003658 -0.025678
# 사진유무       0.000004  0.014928  1.000000  0.023787   0.037739  0.034143
# 조회수int     0.558741  0.607249  0.023787  1.000000   0.045075  0.055877
# dayofweek -0.006851 -0.003658  0.037739  0.045075   1.000000  0.626657
# holiday   -0.014517 -0.025678  0.034143  0.055877   0.626657  1.000000

# %%
mask = np.array(clien[['추천수', '리플수', '사진유무', '조회수int','dayofweek', 'holiday']].corr())
mask[np.tril_indices_from(mask)] = False #array의 1 값을 기준으로 상위부분 출력제외

mask
# Out:
# array([[ 0.00000000e+00,  4.51798889e-01,  4.13438164e-06,
#          5.58741439e-01, -6.85084068e-03, -1.45165261e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  1.49275829e-02,
#          6.07249308e-01, -3.65764138e-03, -2.56782258e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          2.37869261e-02,  3.77389699e-02,  3.41427052e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  4.50749729e-02,  5.58766005e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  6.26657004e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
# 상관계수의 Heatmap
fig, ax = plt.subplots()
fig.set_size_inches(40,10)
sns.heatmap(clien[['추천수', '리플수', '사진유무', '조회수int','dayofweek', 'holiday']].corr(), 
            mask = mask, vmax=1, square=True, annot=True )

# %% [markdown]
# ### 조회수와 추천수에 상관관계가 있고
# ### 그 다음은 휴일 여부 이다
# ### 어그로를 끌기 위해서는 날짜, 시간을 맞춰 조회수를 올리는것이 유효하다
# ## 의외로 사진유무는 크게 중요하지가 않다

# %%
sns.pairplot(clien,
            x_vars=['추천수', '리플수', '사진유무', '조회수int','dayofweek', 'holiday'],
            y_vars=['추천수', '리플수', '사진유무', '조회수int','dayofweek', 'holiday'],
            kind='reg',
             height=6
            )

# %%
clienSorted = clien.sort_values('조회수int',ascending=False)

# %%
clienSorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133743 entries, 83738 to 80164
# Data columns (total 21 columns):
# 추천수          133743 non-null int64
# 게시판          133743 non-null object
# 제목           133743 non-null object
# 리플수          133743 non-null int64
# 아이디          133743 non-null object
# 조회수          133743 non-null object
# 날짜           133743 non-null object
# 문서번호         133743 non-null int64
# 사진유무         133743 non-null int64
# 조회수int       133743 non-null int64
# date         133743 non-null object
# year         133743 non-null int64
# month        133743 non-null int64
# day          133743 non-null int64
# hour         133743 non-null int64
# minute       133743 non-null int64
# second       133743 non-null int64
# dayofweek    133743 non-null int64
# 설명           12087 non-null object
# holiday      133743 non-null int64
# 요일           133743 non-null object
# dtypes: int64(13), object(8)
# memory usage: 22.4+ MB

# %%
#상위 10%글 특징 분석
clien10 = clienSorted.loc[:13567,]

# %%
# 제일 많이 올린사람 
# 제일 많이 언급된 키워드
idCount =clien10.groupby('아이디').아이디.count()

# %%
idCount=pd.DataFrame(idCount)

# %%
idCount.columns = ['count']

# %%
idCount.sort_values('count',ascending=False).head(10)
# Out:
#              count
# 아이디
# 파이랜            802
# 외선이            324
# 줏엉             318
# 거_미            277
# 아침에커피한잔        247
# 아름다워용          227
# Rabbitbunny    208
# 25th           193
# પ નુલુંગ ખਅ    190
# 열린눈            179

# %%
clien[clien['아이디']=='파이랜'].sort_values('조회수int',ascending = False).head(10)
# Out:
#         추천수 게시판                           제목  리플수  아이디     조회수  \
# 131026   41  모공       (후방) 12월 성진국 ㅊㅈ 순위.jpg  113  파이랜  63.5 k
# 118112    8  모공          (후방) 대만 식당의 도우미.jpg   49  파이랜  63.2 k
# 118102    5  모공             (후방) 사우나 민폐녀.jpg   44  파이랜  61.0 k
# 14822    30  모공        (후방) 얼굴 위주 성진국 ㅊㅈ.gif   92  파이랜  53.5 k
# 108001   49  모공  (후방) 노출이 과하다는 지적 받은 김민아.gif   36  파이랜  52.6 k
# 41385   112  모공             디즈니를 건드린 윾튜브.jpg   50  파이랜  52.5 k
# 85647    31  모공              김민아 아나운서 근황.jpg   66  파이랜  52.0 k
# 111404   21  모공              (후방) 골반 자랑녀.jpg   59  파이랜  51.6 k
# 133335   10  모공  (19) ㄱㅊ 빨면 50만원 내기 한 커플.jpg   45  파이랜  51.4 k
# 91530     9  모공          (후방) 메불메 갈리는 몸매.jpg   30  파이랜  51.4 k
#
#                          날짜      문서번호  사진유무  조회수int  ...  year  month  day  \
# 131026  2019-12-02 15:16:14  14350861     0   63500  ...  2019     12    2
# 118112  2019-12-08 16:07:47  14371165     0   63200  ...  2019     12    8
# 118102  2019-12-08 16:13:20  14371179     0   61000  ...  2019     12    8
# 14822   2020-01-25 02:58:20  14526218     0   53500  ...  2020      1   25
# 108001  2019-12-12 18:50:41  14386530     0   52600  ...  2019     12   12
# 41385   2020-01-11 17:48:18  14486624     1   52500  ...  2020      1   11
# 85647   2019-12-24 09:57:55  14421775     0   52000  ...  2019     12   24
# 111404  2019-12-11 12:17:29  14381206     0   51600  ...  2019     12   11
# 133335  2019-12-01 10:53:36  14347038     0   51400  ...  2019     12    1
# 91530   2019-12-21 04:57:17  14412398     1   51400  ...  2019     12   21
#
#         hour  minute  second  dayofweek   설명 holiday  요일
# 131026    15      16      14          0  NaN       0   월
# 118112    16       7      47          6  NaN       1   일
# 118102    16      13      20          6  NaN       1   일
# 14822      2      58      20          5   설날       1   토
# 108001    18      50      41          3  NaN       0   목
# 41385     17      48      18          5  NaN       1   토
# 85647      9      57      55          1  NaN       0   화
# 111404    12      17      29          2  NaN       0   수
# 133335    10      53      36          6  NaN       1   일
# 91530      4      57      17          5  NaN       1   토
#
# [10 rows x 21 columns]

# %%
clien[clien['아이디']=='외선이'].sort_values('조회수int',ascending = False).head(10)
# Out:
#        추천수 게시판                            제목  리플수  아이디     조회수  \
# 13986  283  모공               드러난 이상용의 실체.jpg  143  외선이  59.6 k
# 18687  324  모공             추미애 법무부장관의 혜안.jpg   55  외선이  58.3 k
# 75267  217  모공                어제 이은재의 행위.gif  112  외선이  53.8 k
# 73622   85  모공         딸의 머리카락을 밀어버리는 엄마.gif  150  외선이  51.7 k
# 99972  220  모공                       미친놈.jpg   86  외선이  50.9 k
# 8423   102  모공  따릉이 타고 자전거 대회 출전한 남자.jpg+gif  115  외선이  47.0 k
# 25076   32  모공   기숙사를 비운 사이에 CPU를 교체한 룸메.jpg   92  외선이  45.9 k
# 89627   29  모공                 초아가 화난 사건.jpg   46  외선이  45.0 k
# 89782   34  모공      후방을 올려도 정도가 있지 정말 너무하네요.   25  외선이  44.2 k
# 55340    6  모공           새로 공개된 만능 미니 PC.jpg   53  외선이  43.7 k
#
#                         날짜      문서번호  사진유무  조회수int  ...  year  month  day  \
# 13986  2020-01-25 18:59:42  14527398     1   59600  ...  2020      1   25
# 18687  2020-01-23 06:50:59  14520732     0   58300  ...  2020      1   23
# 75267  2019-12-28 09:30:35  14436829     1   53800  ...  2019     12   28
# 73622  2019-12-29 09:31:57  14439470     0   51700  ...  2019     12   29
# 99972  2019-12-17 08:45:32  14399150     0   50900  ...  2019     12   17
# 8423   2020-01-28 16:55:03  14535412     1   47000  ...  2020      1   28
# 25076  2020-01-20 04:56:20  14511244     1   45900  ...  2020      1   20
# 89627  2019-12-22 11:17:26  14415451     0   45000  ...  2019     12   22
# 89782  2019-12-22 08:59:05  14415211     0   44200  ...  2019     12   22
# 55340  2020-01-05 16:33:13  14466278     1   43700  ...  2020      1    5
#
#        hour  minute  second  dayofweek   설명 holiday  요일
# 13986    18      59      42          5   설날       1   토
# 18687     6      50      59          3  NaN       0   목
# 75267     9      30      35          5  NaN       1   토
# 73622     9      31      57          6  NaN       1   일
# 99972     8      45      32          1  NaN       0   화
# 8423     16      55       3          1  NaN       0   화
# 25076     4      56      20          0  NaN       0   월
# 89627    11      17      26          6  NaN       1   일
# 89782     8      59       5          6  NaN       1   일
# 55340    16      33      13          6  NaN       1   일
#
# [10 rows x 21 columns]

# %% [markdown]
# ## 확장자를 무조건 붙여야 한다. gif .jpg .avi등이 유효하다
# ## 사진유무와는 관계 없지만 사진이 들어갔다고 표시된 글들의 조회수가 높다
# ## 클리앙 인터페이스상 사진 유무를 확인하기가 어려우므로 이러한 현상이 발생

# %%
import nltk
from konlpy.corpus import kolaw
from konlpy.tag import Okt
from wordcloud import WordCloud
t = Okt()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
clien10
# Out:
#          추천수 게시판                                      제목  리플수        아이디  \
# 83738   1058  모공  (내용 2차 추가) 분당구 닭강정 사건, 학폭이 아니라 범죄였습니다.  240       헤바닐리
# 83978    448  모공                 (분당구 수내동) 닭강정을 무료로 드립니다  294       헤바닐리
# 71043     41  모공                             위기의 백종원.gif   46       25th
# 8624     188  모공                  대한항공 베테랑 승무원들이 자원했다는군요   17  Riverside
# 132982     9  모공                 못생긴 사람중에 가장 예쁘다는 사람.gif  107     마이크피아자
# ...      ...  ..                                     ...  ...        ...
# 12335      3  모공                          아기고양이 업은 개.gif    9      Myayu
# 92990     73  모공  진혜원 검사 '이중 기소는 일사부재리 위반이며, 검찰 권한 남용이다'   17        라쿠니
# 20         0  모공                               텍사스찌개.jpg   15    아침에커피한잔
# 43566      0  모공                 로고 모자이크 처리가 이상한 KBS.jpg   13        외선이
# 13567      6  모공                    민주당 총선 승리의 주역이될 다크호스    5     alkits
#
#             조회수                   날짜      문서번호 사진유무  조회수int        date  year  \
# 83738   180.1 k  2019-12-25 01:39:41  14424677    Y  180100  2019-12-25  2019
# 83978   149.4 k  2019-12-24 22:47:24  14424322    N  149400  2019-12-24  2019
# 71043   110.9 k  2019-12-30 13:02:08  14443429    Y  110900  2019-12-30  2019
# 8624    109.3 k  2020-01-28 15:25:08  14535081    N  109300  2020-01-28  2020
# 132982  102.8 k  2019-12-01 14:49:12  14347708    Y  102800  2019-12-01  2019
# ...         ...                  ...       ...  ...     ...         ...   ...
# 12335      5807  2020-01-26 19:42:41  14529763    Y    5807  2020-01-26  2020
# 92990      5807  2019-12-20 12:44:23  14410133    N    5807  2019-12-20  2019
# 20         5806  2020-01-31 23:53:48  14547670    Y    5806  2020-01-31  2020
# 43566      5806  2020-01-10 17:06:15  14483541    Y    5806  2020-01-10  2020
# 13567      5806  2020-01-25 23:51:53  14527971    Y    5806  2020-01-25  2020
#
#         month  day  hour  minute  second  dayofweek     설명  holiday
# 83738      12   25     1      39      41          2  크리스마스        1
# 83978      12   24    22      47      24          1    NaN        0
# 71043      12   30    13       2       8          0    NaN        0
# 8624        1   28    15      25       8          1    NaN        0
# 132982     12    1    14      49      12          6    NaN        1
# ...       ...  ...   ...     ...     ...        ...    ...      ...
# 12335       1   26    19      42      41          6     설날        1
# 92990      12   20    12      44      23          4    NaN        0
# 20          1   31    23      53      48          4    NaN        0
# 43566       1   10    17       6      15          4    NaN        0
# 13567       1   25    23      51      53          5     설날        1
#
# [16407 rows x 20 columns]

# %%
a=""
b = a.join(clien10['제목'])

# %%
words = t.nouns(b)

# %%
# 불용어 추가
stop_words = ['제','월','일','조','것','이','입','애','정',
              '수','관','때','그','바','위','및','안','장',
             '집','요','전','거','한','후','명','글','말','왜','분','차','저']
words = [each_word for each_word in words if each_word not in stop_words]
words
# Out:
# ['내용',
#  '추가',
#  '분당구',
#  '닭강정',
#  '사건',
#  '학폭',
#  '범죄',
#  '분당구',
#  '수내동',
#  '닭강정',
#  '무료',
#  '위기',
#  '백종원',
#  '대한항공',
#  '베테',
#  '승무원',
#  '자원',
#  '사람',
#  '가장',
#  '사람',
#  '아이유',
#  '검소',
#  '홍콩',
#  '아파트',
#  '내부',
#  '실패',
#  '돈',
#  '대기',
#  '후기',
#  '전자',
#  '홍보팀',
#  '못',
#  '걸',
#  '신봉선',
#  '프로스펙스',
#  '근황',
#  '휴대폰',
#  '구입',
#  '연',
#  '수입',
#  '남자',
#  '쿠팡',
#  '맨',
#  '서울',
#  '사진',
#  '보고',
#  '놀란',
#  '이유',
#  '회사',
#  '근처',
#  '이비인후과',
#  '상황',
#  '토이스토리',
#  '아이',
#  '고양이',
#  '최강',
#  '미녀',
#  '가게',
#  '주인',
#  '휴업',
#  '사유',
#  '실화',
#  '여고',
#  '남자',
#  '교생',
#  '가면',
#  '조금',
#  '지하철',
#  '타고',
#  '멤버',
#  '아이돌',
#  '사진',
#  '보정',
#  '양준',
#  '서태지',
#  '부인',
#  '정말',
#  '미인',
#  '시골',
#  '헬스장',
#  '현실',
#  '카카오',
#  '뱅크',
#  '인기',
#  '이유',
#  '마침내',
#  '승리',
#  '깃발',
#  '여유',
#  '대충',
#  '근황',
#  '슈가',
#  '맨',
#  '이소은',
#  '편',
#  '방청객',
#  '김포',
#  '사생활',
#  '보호',
#  '주택',
#  '몸',
#  '이세돌',
#  '이슬람',
#  '율법',
#  '한국',
#  '압도',
#  '세계',
#  '위인',
#  '샾',
#  '이지혜',
#  '근황',
#  '샤를',
#  '리즈',
#  '테론',
#  '근황',
#  '베트남',
#  '한국',
#  '딸기',
#  '가격',
#  '결혼',
#  '포기',
#  '청춘',
#  '안철수',
#  '남자',
#  '시골의사',
#  '박경철',
#  '황남',
#  '운동',
#  '이유',
#  '남자',
#  '혼자',
#  '괌',
#  '폰카',
#  '사진',
#  '시각',
#  '막내',
#  '세뱃돈',
#  '근황',
#  '독자',
#  '보유',
#  '유투',
#  '버',
#  '클라스',
#  '현재',
#  '중국',
#  '상황',
#  '사진',
#  '그랜저',
#  '근황',
#  '공항',
#  '게이트',
#  '앞',
#  '사람',
#  '친구',
#  '화장',
#  '더',
#  '이병헌',
#  '광고',
#  '촬영',
#  '태도',
#  '수준',
#  '지하철역',
#  '공익',
#  '광고',
#  '쵝오우',
#  '사진',
#  '보고',
#  '놀란',
#  '이유',
#  '후방',
#  '그냥',
#  '돌',
#  '프랑스',
#  '오늘',
#  '길거리',
#  '창녀',
#  '소리',
#  '전설',
#  '시상식',
#  '사회자',
#  '후기',
#  '파주',
#  '가족',
#  '펜션',
#  '마카롱',
#  '한식',
#  '요즘',
#  '백화점',
#  '건물',
#  '디자인',
#  '베트남',
#  '꿈',
#  '월급',
#  '요즘',
#  '강남',
#  '인기',
#  '면방',
#  '요즘',
#  '대한민국',
#  '택배',
#  '근황',
#  '김포',
#  '아파트',
#  '가격',
#  '무',
#  '주택',
#  '클라스',
#  '핸드폰',
#  '자랑',
#  '아이유',
#  '버스',
#  '여자',
#  '머리',
#  '만화',
#  '서양인',
#  '상상력',
#  '증거',
#  '삼성',
#  '병원',
#  '근황',
#  '버',
#  '사람',
#  '가계부',
#  '여보',
#  '바람',
#  '핀',
#  '연기대상',
#  '배우',
#  '코딩',
#  '공익',
#  '진짜',
#  '근황',
#  '백종원',
#  '기부',
#  '척',
#  '이유',
#  '진심',
#  '이혼',
#  '검찰',
#  '내부',
#  '분위',
#  '후방',
#  '노',
#  '팬티',
#  '시미',
#  '켄',
#  '방송',
#  '츠나마',
#  '구',
#  '사쿠',
#  '유아',
#  '여자',
#  '오르가즘',
#  '느낌',
#  '신혼여행',
#  '간',
#  '신재은',
#  '근황',
#  '한국',
#  '공무원',
#  '오늘',
#  '대구',
#  '부동산',
#  '까페',
#  '난리',
#  '박',
#  '소담',
#  '근육',
#  '회사',
#  '영양사',
#  '애인',
#  '후방',
#  '모델',
#  '전보람',
#  '카톡',
#  '잘못',
#  '친누나',
#  '신화',
#  '앤디',
#  '결혼',
#  '이유',
#  '새해',
#  '호',
#  '방송사고',
#  '검찰',
#  '폭발',
#  '막장',
#  '나라',
#  '약국',
#  '근황',
#  '원룸',
#  '역대',
#  '여대생',
#  '입자',
#  '조국',
#  '교수',
#  '트윗',
#  '손',
#  '잡고',
#  '줄',
#  '춘천',
#  '지은',
#  '이유',
#  '후방',
#  '진국',
#  '순위',
#  '후방',
#  '대만',
#  '식당',
#  '도우미',
#  '봉준호',
#  '헐리우드',
#  '여배우',
#  '연봉',
#  '실수',
#  '령액',
#  '필리핀',
#  '혼혈',
#  '인생',
#  '한탄',
#  '명동',
#  '근황',
#  '설리',
#  '고양이',
#  '고블린',
#  '근황',
#  '우한',
#  '국자',
#  '방',
#  '모습',
#  '후방',
#  '알',
#  '아두',
#  '도움',
#  '이동욱',
#  '도깨비',
#  '로',
#  '광고',
#  '전부',
#  '거절',
#  '설',
#  '전날',
#  '초',
#  '며느리',
#  '개발자',
#  '곡',
#  '소리',
#  '여자',
#  '심취',
#  '회사',
#  '꼬',
#  '힘',
#  '천조국',
#  '신의',
#  '음식',
#  '아내',
#  '톡',
#  '돈',
#  '돈까스',
#  '부부',
#  '모',
#  '아이',
#  '법',
#  '신한카드',
#  '신의',
#  '웨이브',
#  '디씨',
#  '주진모',
#  '갤러리',
#  '근황',
#  '후방',
#  '사우나',
#  '민폐',
#  '녀',
#  '경북',
#  '전자공학',
#  '취업률',
#  '속보',
#  '법무부',
#  '오전',
#  '윤석열',
#  '호출',
#  '윤석열',
#  '거부',
#  '우리',
#  '사무실',
#  '고양이',
#  '진심',
#  '여자도',
#  '가슴',
#  '점점',
#  '룸',
#  '근황',
#  '요즘',
#  '한국',
#  '인기',
#  '불매운동',
#  '직장인',
#  '중견',
#  '중소',
#  '비교',
#  '처제',
#  '성폭행',
#  '손흥민',
#  '계',
#  '동네',
#  '바보',
#  '게',
#  '생각',
#  '환상',
#  '고추',
#  '남자',
#  '법',
#  '또',
#  '음주',
#  '사고',
#  '혈압',
#  '주의',
#  '해외',
#  '윤종신',
#  '근황',
#  '사람',
#  '서울',
#  '구석',
#  '집값',
#  '후방',
#  '화가',
#  '긴급',
#  '오늘',
#  '아침',
#  '공지',
#  '보배',
#  '펌',
#  '회사',
#  '복지',
#  '여지',
#  '친구',
#  '싱하',
#  '이제',
#  '강남',
#  '입성',
#  '물건',
#  '너',
#  '간호학',
#  '여신',
#  '김희철',
#  '모모',
#  '멸애',
#  '가장',
#  '멘붕',
#  '온',
#  '인물',
#  '이상용',
#  '실체',
#  '윤석열',
#  '거짓말',
#  '포방터',
#  '돈',
#  '주변',
#  '상인',
#  '일화',
#  '눈',
#  '욕',
#  '결혼',
#  '더',
#  '일찍',
#  '걸',
#  '후회',
#  '운전',
#  '진짜',
#  '신입사원',
#  '화장실',
#  '쓰레기통',
#  '회장',
#  '딸',
#  '세번',
#  '확',
#  '진자',
#  '얘기',
#  '이유',
#  '큰일',
#  '냉',
#  '동생',
#  '알',
#  '며느리',
#  '설날',
#  '남산',
#  '부장',
#  '미스캐스팅',
#  '논란',
#  '추미애',
#  '인사',
#  '검찰',
#  '격노',
#  '소리',
#  '이상화',
#  '선수',
#  '신혼',
#  '생활',
#  '독일',
#  '헬스장',
#  '인치',
#  '티비',
#  '사자',
#  '뼈',
#  '림',
#  '펌',
#  '돈까스',
#  '유모차',
#  '끌',
#  '고온',
#  '부부',
#  '추미애',
#  '법무부',
#  '장관',
#  '혜안',
#  '대한민국',
#  '현재',
#  '상황',
#  '세계',
#  '방송',
#  '역사상',
#  '레전드',
#  '장면',
#  '한국',
#  '명품',
#  '가전',
#  '김태리',
#  '졸업사진',
#  '단',
#  '변화',
#  '이낙연',
#  '총리',
#  '화',
#  '낫다',
#  '박근혜',
#  '지지자',
#  '근황',
#  '분당',
#  '닭강정',
#  '사건',
#  '진행',
#  '상황',
#  '추가',
#  '실수',
#  '카톡',
#  '부서',
#  '직원',
#  '후기',
#  '추가',
#  '마눌',
#  '처음',
#  '대박',
#  '말실수',
#  '북부',
#  '사람',
#  '특징',
#  '한국인',
#  '조금',
#  '충격',
#  '미국',
#  '설거지',
#  '방법',
#  '그랜져',
#  '동호회',
#  '참사',
#  '후기',
#  '고민정',
#  '아나운서',
#  '편의점',
#  '커플',
#  '영드',
#  '정말',
#  '여배우',
#  '중국인',
#  '유학생',
#  '외침',
#  '실제',
#  '미국',
#  '국세청',
#  '기동',
#  '타격',
#  '프랑스',
#  '아이',
#  '급식',
#  '수준',
#  '진짜',
#  '세금',
#  '질병',
#  '관리',
#  '본부',
#  '대통령',
#  '여자',
#  '후방',
#  '유비',
#  '아내',
#  '손부인',
#  '청와대',
#  '간',
#  '수지',
#  '이번',
#  '새해',
#  '꼭',
#  '그녀',
#  '이별',
#  '전여친',
#  '미투',
#  '진짜',
#  '검찰',
#  '추미애',
#  '장관',
#  '착수',
#  '논란',
#  '위곡',
#  '웃기',
#  '자유당',
#  '셀프',
#  '환',
#  '자폭',
#  '딴지',
#  '펌',
#  '광교',
#  '거실',
#  '뷰',
#  '끼',
#  '쇼',
#  '웹툰작가',
#  '석',
#  '판교',
#  '쪽',
#  '난리',
#  '남해',
#  '바다',
#  '별로',
#  '툽',
#  '경비원',
#  '피지',
#  '컬',
#  '이유',
#  '오늘',
#  '장도리',
#  '대박',
#  '장나라',
#  '은근',
#  '망언',
#  '조기',
#  '연봉',
#  '실수',
#  '령',
#  '이군',
#  '포터',
#  '전기차',
#  '서양',
#  '판',
#  '합법',
#  '동안',
#  '윤',
#  '총장',
#  '베프',
#  '여고생',
#  '중고',
#  '거래',
#  '후기',
#  '후방',
#  '취해',
#  '미국',
#  '휴가',
#  '배성재',
#  '아나운서',
#  '근황',
#  '실황',
#  '추미애',
#  '장관',
#  '검찰총장',
#  '거역',
#  '장용',
#  '준',
#  '정도',
#  '역대',
#  '추미애',
#  '장관',
#  '식사',
#  '농담',
#  '이란',
#  '미국',
#  '이유',
#  '머리',
#  '중국',
#  '여자',
#  '의료',
#  '진',
#  '의사',
#  '경고',
#  '음식',
#  '옆',
#  '직원',
#  '모니터',
#  '다시',
#  '장면',
#  '유시민',
#  '이사장',
#  '어제',
#  '이슈',
#  '오피',
#  '녀',
#  '근황',
#  '포방터',
#  '돈까스',
#  '내부',
#  '애플',
#  '가로수길',
#  '소화전',
#  '돈',
#  '줄',
#  '동거',
#  '남자친구',
#  '장거리',
#  '연애',
#  '시작',
#  '개월',
#  '로',
#  '살',
#  '비법',
#  '펌',
#  '남편',
#  '갑자기',
#  '포르쉐',
#  '일본',
#  '치바현',
#  '근황',
#  '일본인',
#  '장수',
#  '노인',
#  '특징',
#  '엑셀',
#  '왕초보',
#  '꿀팁',
#  '한국',
#  '가장',
#  '무시',
#  '나라',
#  '일본',
#  '불매',
#  '운동',
#  '후회',
#  '한국',
#  '고등학교',
#  '여친',
#  '공부',
#  '일본',
#  '하네다공항',
#  '현재상황',
#  '근황',
#  '추미애',
#  '걸',
#  '아빠',
#  '세부',
#  '온',
#  '살',
#  '코피노',
#  '아이',
#  '아침',
#  '후기',
#  '추가',
#  '전주',
#  '톨게이트',
#  '현판',
#  '비밀',
#  '법무부',
#  '입장',
#  '금',
#  '화류',
#  '험담',
#  '보배',
#  '펌',
#  '재중',
#  '작품',
#  '후방',
#  '주의',
#  '제자',
#  '장용진',
#  '예언',
#  '보배',
#  '펌',
#  '후쿠시마',
#  '사태',
#  '큰일',
#  '이군',
#  '전남',
#  '완도군',
#  '매물',
#  '주택',
#  '내',
#  '남친',
#  '헬스',
#  '갤러리',
#  '이세돌',
#  '대박',
#  '강',
#  '후방',
#  '쩍벌',
#  '민폐',
#  '녀',
#  '강변북로',
#  '패기',
#  '남',
#  '근황',
#  '미국',
#  '매우',
#  '사회',
#  '문제',
#  '외국인',
#  '조선시대',
#  '주막',
#  '어제',
#  '명의',
#  '발언',
#  '우리',
#  '아파트',
#  '점',
#  '나경원',
#  '김현정',
#  '라디오',
#  '미국',
#  '간',
#  '도끼',
#  '근황',
#  '연예인',
#  '근황',
#  '세계',
#  '주목',
#  '의사',
#  '한지민',
#  '근황',
#  '스켈레톤',
#  '윤',
#  '성빈',
#  '근황',
#  '어제',
#  '이은재',
#  '행위',
#  '인생',
#  '과정',
#  '모델',
#  '핏',
#  '때문',
#  '하루',
#  '매진',
#  '옷',
#  '속보',
#  '이인영',
#  '갓',
#  '영',
#  '이유',
#  '애니',
#  '제시',
#  '형태',
#  '여친',
#  '애무',
#  '토',
#  '남자',
#  '디시',
#  '인생',
#  '최대',
#  '업적',
#  '생각',
#  '적',
#  '여자',
#  '연예인',
#  '머리',
#  '독일',
#  '한국',
#  '버섯',
#  '시작',
#  '코',
#  '방',
#  '해결',
#  '친구',
#  '를',
#  '후방',
#  '얼굴',
#  '위주',
#  '진국',
#  '급여',
#  '상철',
#  '돌',
#  '여사',
#  '친',
#  '심재철',
#  '검사',
#  '니',
#  '쇼',
#  '알',
#  '금',
#  '지금',
#  '이해',
#  '여자',
#  '행동',
#  '이건희',
#  '가수',
#  '최현석',
#  '셰프',
#  '근황',
#  '마트',
#  '진상',
#  '녀',
#  '레전드',
#  '장나라',
#  '점점',
#  '나이',
#  '오피',
#  '성매매',
#  '검사',
#  '근황',
#  '덩케르크',
#  '촬영장',
#  '감독',
#  '당직',
#  '근무',
#  '여직원',
#  '잠실',
#  '롯데',
#  '유니클로',
#  '상황',
#  '백종원',
#  '빵집',
#  '맘',
#  '카페',
#  '남편',
#  '용돈',
#  '근황',
#  '오바마',
#  '정말',
#  '최악',
#  '대통령',
#  '돈',
#  '더',
#  '코리아',
#  '닭강정',
#  '사장',
#  '현재상황',
#  '후방',
#  '노출',
#  '과',
#  '지적',
#  '김민아',
#  '펌',
#  '신랑',
#  '여학생',
#  '선물',
#  '디즈니',
#  '윾',
#  '튜브',
#  '잠실',
#  '고오',
#  '아파트',
#  '송년회',
#  '클라스',
#  '설리',
#  '친오빠',
#  '인스타그램',
#  '한글',
#  '사랑',
#  '에쿠스',
#  '파티',
#  '상의',
#  '탈의',
#  '긴머리',
#  '술',
#  '랜더',
#  '보니하니',
#  '논란',
#  '짤',
#  '한장',
#  '요약',
#  '듯수',
#  '개',
#  '월간',
#  '대화',
#  '부부',
#  '최신',
#  '한류',
#  '유행',
#  '국산',
#  '판매량',
#  '성인',
#  '용품',
#  '리뷰',
#  '한번',
#  '소설',
#  '속',
#  '가장',
#  '문장',
#  '귤',
#  '박스',
#  '제일',
#  '밑바닥',
#  '근황',
#  '여자',
#  '린',
#  ...]

# %%
# 상위 50개 단어 확인
ko = nltk.Text(words)
ko.vocab().most_common(50)
# Out:
# [('근황', 789),
#  ('후방', 771),
#  ('이유', 453),
#  ('한국', 379),
#  ('펌', 342),
#  ('검찰', 332),
#  ('일본', 302),
#  ('오늘', 278),
#  ('속보', 231),
#  ('우한', 219),
#  ('사람', 213),
#  ('중국', 210),
#  ('사진', 206),
#  ('추미애', 197),
#  ('장관', 186),
#  ('조국', 183),
#  ('윤석열', 176),
#  ('진짜', 173),
#  ('여자', 171),
#  ('미국', 168),
#  ('검사', 154),
#  ('남자', 150),
#  ('요즘', 148),
#  ('돈', 133),
#  ('상황', 131),
#  ('사건', 130),
#  ('민주당', 126),
#  ('폐렴', 125),
#  ('진중권', 125),
#  ('인사', 122),
#  ('논란', 118),
#  ('녀', 117),
#  ('교수', 116),
#  ('손흥민', 116),
#  ('대통령', 111),
#  ('주의', 109),
#  ('단독', 109),
#  ('결혼', 107),
#  ('법', 99),
#  ('아파트', 97),
#  ('정말', 94),
#  ('관련', 94),
#  ('회사', 91),
#  ('나경원', 90),
#  ('중', 90),
#  ('사장', 88),
#  ('아들', 88),
#  ('가장', 87),
#  ('최고', 87),
#  ('사고', 86)]

# %%
# 상위 1000개만  word cloud 로 그리기
data = ko.vocab().most_common(4000)
tmp_data = dict(data)

# %%
from PIL import Image
import numpy as np
clien = np.array(Image.open('./logo3.png'))

from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(clien)

# %%
wordcloud = WordCloud(background_color="White",
                     font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling=0.2,
                     mask=clien,
                     min_font_size=1,
                     max_font_size=80,
                      width = 1600,
                      height = 800
                     ).generate_from_frequencies(tmp_data)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis('off')
plt.show()
